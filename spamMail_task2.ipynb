# %%
import pandas as pd

# %%
import os 
os.listdir("Downloads")
# Out:
# ['Automated Rain Guard Using Rain SensorRESEARCH PAPER.docx',
#  'aws_certificate',
#  'circles.pdf',
#  'CLOUD COMPUTING.pdf',
#  'Data_Analytics_Essentials_certificate_yelurijanani-gmail-com_efc93cdb-6c04-46a7-b3ca-11601d71105d.pdf',
#  'Desktop - Shortcut.lnk',
#  'desktop.ini',
#  'diagram-export-3-9-2026-12_00_12-PM.png',
#  'falimy.jpeg',
#  'Final Documentation NutriGraph Ai_final.pdf',
#  'Final Documentation NutriGraph Ai_final1.pdf',
#  'Git-2.51.0.2-64-bit (1).exe',
#  'Git-2.51.0.2-64-bit.exe',
#  'Janani Yeluri (1).pdf',
#  'Janani Yeluri.pdf',
#  'janani.jpeg',
#  'Janani_Yeluri_Resume.docx',
#  'Janani_Yeluri_Resume.pdf',
#  'Janani_Yeluri_Resume.pdf.pdf',
#  'Mini Project- Batch 18-1 (1).pptx',
#  'Mini Project- Batch 18-1 (2).pptx',
#  'Mini Project- Batch 18-1.pptx',
#  'NutriGraph AI_RESEARCH PAPER (1).docx',
#  'NutriGraph AI_RESEARCH PAPER (2).docx',
#  'NutriGraph AI_RESEARCH PAPER (3).docx',
#  'NutriGraph AI_RESEARCH PAPER (4) (1).docx',
# ...

# %%
import os
os.listdir("Downloads/sms+spam+collection")
# Out:
# ['readme', 'SMSSpamCollection']

# %%
import pandas as pd
df=pd.read_csv("Downloads/sms+spam+collection/SMSSpamCollection", sep="\t", names=["label","message"])

# %%
df.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.shape
# Out:
# (5572, 2)

# %%
df.isnull().sum()
# Out:
# label      0
# message    0
# dtype: int64

# %%
df["label"].value_counts()
# Out:
# label
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
df["message"
    ].head()
# Out:
# 0    Go until jurong point, crazy.. Available only ...
# 1                        Ok lar... Joking wif u oni...
# 2    Free entry in 2 a wkly comp to win FA Cup fina...
# 3    U dun say so early hor... U c already then say...
# 4    Nah I don't think he goes to usf, he lives aro...
# Name: message, dtype: object

# %%
df["message_lower"]=df["message"].str.lower()

# %%
df[["message", "message_lower"]].head()
# Out:
#                                              message  \
# 0  Go until jurong point, crazy.. Available only ...
# 1                      Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup fina...
# 3  U dun say so early hor... U c already then say...
# 4  Nah I don't think he goes to usf, he lives aro...
#
#                                        message_lower
# 0  go until jurong point, crazy.. available only ...
# 1                      ok lar... joking wif u oni...
# 2  free entry in 2 a wkly comp to win fa cup fina...
# 3  u dun say so early hor... u c already then say...
# 4  nah i don't think he goes to usf, he lives aro...

# %%
token=df["message_lower"][0]

# %%
print(token)
# Out:
# go until jurong point, crazy.. available only in bugis n great world la e buffet... cine there got amore wat...

# %%
token.split()
# Out:
# ['go',
#  'until',
#  'jurong',
#  'point,',
#  'crazy..',
#  'available',
#  'only',
#  'in',
#  'bugis',
#  'n',
#  'great',
#  'world',
#  'la',
#  'e',
#  'buffet...',
#  'cine',
#  'there',
#  'got',
#  'amore',
#  'wat...']

# %%
# !pip install nltk

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords.words('english')[:20]
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been']

# %%
sentence="you need to play basketball"
words=sentence.split()

# %%
filtered_words=[word for word in words if word not in stopwords.words('english')]
print(filtered_words)
# Out:
# ['need', 'play', 'basketball']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer=TfidfVectorizer

# %%
type(vectorizer)
# Out:
# type

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer=TfidfVectorizer()

# %%
type(vectorizer)
# Out:
# sklearn.feature_extraction.text.TfidfVectorizer

# %%
x=vectorizer.fit_transform(df["message_lower"])

# %%
print(x.shape)
# Out:
# (5572, 8713)

# %%
df.shape
# Out:
# (5572, 3)

# %%
y=df["label"]

# %%
y.head()
# Out:
# 0     ham
# 1     ham
# 2    spam
# 3     ham
# 4     ham
# Name: label, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train , y_test = train_test_split(
    x,y,test_size=0.2, random_state=42)

# %%
print(x_train.shape)
# Out:
# (4457, 8713)

# %%
print(x_test.shape)
# Out:
# (1115, 8713)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
model=MultinomialNB()

# %%
model.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
predictions=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test, predictions)

# %%
print(accuracy)
# Out:
# 0.9668161434977578

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.96      1.00      0.98       966
#         spam       1.00      0.75      0.86       149
#
#     accuracy                           0.97      1115
#    macro avg       0.98      0.88      0.92      1115
# weighted avg       0.97      0.97      0.96      1115
